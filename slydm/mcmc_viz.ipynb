# %%
import mcmc
import read_mcmc
from importlib import reload

# %% [markdown]
# # Log Likelihood
# $\log{\mathcal{L}(\Theta)} = \sum_{v_c, v}(\hat{y}_{v_c,v}-y_{v_c,v})^2$
# $y = 4\pi v^2 f(v, v_c)$
# $\Theta = \langle D, e, H, j, k\rangle$
#
# $f(v)=\frac{1}{N(v_0,v_\mathrm{damp})}\exp\left(-\frac{v^2}{v_0^{2}}\right)\mathcal{S}(v_\mathrm{damp}-v)$
# $\mathcal{S}(v_\mathrm{damp}-v)=\frac{1}{1+\exp(-k(v_\mathrm{damp}-v))}$
#
# $v_0=D\left(\frac{v_\mathrm{c}}{100\,\mathrm{km\,s^{-1}}}\right)^e$
# $v_\mathrm{damp}=H\left(\frac{v_\mathrm{c}}{100\,\mathrm{km\,s^{-1}}}\right)^j$

# %%
def show(samples_fname, log_prior_fn, rng=None):
    read_mcmc.estimate(samples_fname)
    read_mcmc.corner_plot(
        samples_fname, 
        consider_burnin=True,
        log_prior_function=log_prior_fn,
        rng=rng)
    read_mcmc.trace_plot(samples_fname)
    return None

# %% [markdown]
# # Uniform priors

# %% [markdown]
# ## Wide Uniform prior (Broken)

# %%
read_mcmc.estimate(
    'mcmc_samples_disks_wide_uniform_prior_amended_likelihood.h5'
)
read_mcmc.corner_plot(
    'mcmc_samples_disks_wide_uniform_prior_amended_likelihood.h5', 
    consider_burnin=True, make_thin=True, 
    rng=[(0., 600.), (0., 3.5), (25., 1.2e3), (0., 4.), (0., 10.e-2)]
)
read_mcmc.trace_plot(
    'mcmc_samples_disks_wide_uniform_prior_amended_likelihood.h5'
)
# Out:
# The chain is shorter than 50 times the integrated autocorrelation time for 5 parameter(s). Use this estimate with caution and run a longer chain!
# N/50 = 107;
# tau: [135.33910685 139.77216565 137.51632297 144.64353659 153.9289747 ]
# $\displaystyle \mathrm{D} = 255.886_{-177.566}^{+170.935}$
# $\displaystyle \mathrm{e} = 1.549_{-0.986}^{+0.976}$
# $\displaystyle \mathrm{H} = 530.396_{-325.519}^{+314.801}$
# $\displaystyle \mathrm{j} = 1.499_{-0.986}^{+0.998}$
# $\displaystyle \mathrm{k} = 0.042_{-0.027}^{+0.027}$
# The chain is shorter than 50 times the integrated autocorrelation time for 5 parameter(s). Use this estimate with caution and run a longer chain!
# N/50 = 107;
# tau: [135.34025591 139.82801031 137.5302414  144.669206   153.9559787 ]
# tau: [135.34025591 139.82801031 137.5302414  144.669206   153.9559787 ]
# burn-in: 307
# thin: 1
# samples shape: (5023, 32, 5)
# ...

# %% [markdown]
# ## Narrow Uniform Prior

# %% [markdown]
# ### Broken

# %%
reload(read_mcmc)
reload(mcmc)
read_mcmc.estimate(
    'mcmc_samples_disks_narrower_uniform_prior_amended_likelihood.h5'
)
read_mcmc.corner_plot(
    'mcmc_samples_disks_narrower_uniform_prior_amended_likelihood.h5', 
    consider_burnin=True, make_thin=True, 
    rng=[(80., 150.), (0.5, 1.5), (150., 500.), (0., 1.5), (0.5e-2, 5.e-2)],
    log_prior_function=mcmc.calc_log_narrower_uniform_prior
)
# Out:
# $\displaystyle \mathrm{D} = 115.037_{-10.247}^{+10.221}$
# $\displaystyle \mathrm{e} = 1.000_{-0.138}^{+0.136}$
# $\displaystyle \mathrm{H} = 300.284_{-68.360}^{+67.475}$
# $\displaystyle \mathrm{j} = 0.447_{-0.237}^{+0.238}$
# $\displaystyle \mathrm{k} = 0.028_{-0.012}^{+0.012}$
# tau: [202.73120293 188.750786   202.37259095 198.00641614 191.97543366]
# burn-in: 405
# thin: 94
# samples shape: (1433, 32, 5)
# Sampling prior
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50000/50000 [01:13<00:00, 681.95it/s]

# %%
reload(read_mcmc)
read_mcmc.trace_plot(
    'mcmc_samples_disks_narrower_uniform_prior_amended_likelihood.h5'
)
# Out:
# tau: [202.45314647 188.52224775 197.83469217 197.01303063 190.24944583]
# burn-in: 404
# thin: 94
# samples shape: (1323, 32, 5)

# %% [markdown]
# ### Fixed

# %%
reload(read_mcmc)
show('mcmc_samples_narrower_uniform_prior_20240606.h5',
     mcmc.calc_log_narrower_uniform_prior)
# Out:
# $\displaystyle \mathrm{D} = 110.965_{-0.4530}^{+0.4582}$
# $\displaystyle \mathrm{e} = 1.014_{-0.0050}^{+0.0049}$
# $\displaystyle \mathrm{H} = 279.746_{-1.3409}^{+1.3644}$
# $\displaystyle \mathrm{j} = 0.588_{-0.0053}^{+0.0052}$
# $\displaystyle \mathrm{k} = 0.035_{-0.0003}^{+0.0003}$
# tau: [191.6915919  248.24449551 241.26120794 229.63023641  67.57567878]
# burn-in: 496
# thin: 33
# samples shape: (539, 64, 5)
# Sampling prior
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 10000/10000 [00:14<00:00, 680.78it/s]
# tau: [191.6915919  248.24449551 241.26120794 229.63023641  67.57567878]
# burn-in: 496
# thin: 33
# samples shape: (539, 64, 5)

# %% [markdown]
# # Wide Gaussian prior

# %% [markdown]
# ## Broken

# %%
reload(read_mcmc)
read_mcmc.estimate('mcmc_samples_disks_wide_gaussian_prior_amended_likelihood.h5')
read_mcmc.corner_plot('mcmc_samples_disks_wide_gaussian_prior_amended_likelihood.h5', 
                      consider_burnin=True,
                      log_prior_function=mcmc.calc_log_gaussian_prior)
# Out:
# $\displaystyle \mathrm{D} = 115.298_{-3.731}^{+3.680}$
# $\displaystyle \mathrm{e} = 0.958_{-0.044}^{+0.046}$
# $\displaystyle \mathrm{H} = 327.624_{-36.742}^{+38.204}$
# $\displaystyle \mathrm{j} = 0.454_{-0.127}^{+0.122}$
# $\displaystyle \mathrm{k} = 0.027_{-0.007}^{+0.007}$
# tau: [43.57770478 42.57861906 54.78923696 54.14482439 51.54834457]
# burn-in: 109
# thin: 21
# samples shape: (169, 32, 5)
# Sampling prior
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 20000/20000 [01:41<00:00, 197.67it/s]

# %%
read_mcmc.trace_plot(
    'mcmc_samples_disks_wide_gaussian_prior_amended_likelihood.h5'
)
# Out:
# tau: [43.57770478 42.57861906 54.78923696 54.14482439 51.54834457]
# burn-in: 109
# thin: 21
# samples shape: (169, 32, 5)

# %% [markdown]
# ## Fixed

# %%
show('mcmc_samples_wide_gaussian_prior_20240606.h5',
     mcmc.calc_log_wide_gaussian_prior,
     rng=[(50., 175.), (0.7, 1.5), (200., 450.), (0., 1.), (2.e-2, 4.2e-2)])
# Out:
# $\displaystyle \mathrm{D} = 110.986_{-0.4567}^{+0.4594}$
# $\displaystyle \mathrm{e} = 1.014_{-0.0050}^{+0.0050}$
# $\displaystyle \mathrm{H} = 279.728_{-1.3574}^{+1.3526}$
# $\displaystyle \mathrm{j} = 0.588_{-0.0052}^{+0.0052}$
# $\displaystyle \mathrm{k} = 0.035_{-0.0003}^{+0.0003}$
# WARNING:root:Too few points to create valid contours
# tau: [ 49.60496834  62.2454281  186.79898063 187.27216599  38.21636265]
# burn-in: 374
# thin: 19
# samples shape: (691, 64, 5)
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# Sampling prior
# ...

# %%
show('mcmc_samples_wide_gaussian_prior_20240606.h5',
     mcmc.calc_log_wide_gaussian_prior
)
# Out:
# $\displaystyle \mathrm{D} = 110.986_{-0.4567}^{+0.4594}$
# $\displaystyle \mathrm{e} = 1.014_{-0.0050}^{+0.0050}$
# $\displaystyle \mathrm{H} = 279.728_{-1.3574}^{+1.3526}$
# $\displaystyle \mathrm{j} = 0.588_{-0.0052}^{+0.0052}$
# $\displaystyle \mathrm{k} = 0.035_{-0.0003}^{+0.0003}$
# tau: [ 49.60496834  62.2454281  186.79898063 187.27216599  38.21636265]
# burn-in: 374
# thin: 19
# samples shape: (691, 64, 5)
# Sampling prior
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 10000/10000 [00:19<00:00, 512.63it/s]
# tau: [ 49.60496834  62.2454281  186.79898063 187.27216599  38.21636265]
# burn-in: 374
# thin: 19
# samples shape: (691, 64, 5)
